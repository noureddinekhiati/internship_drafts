# %%
from google.colab import drive
drive.mount('/content/drive',force_remount=True)
# Out:
# Mounted at /content/drive

# %%
# !pip install google-search-results
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#   Created wheel for google-search-results: filename=google_search_results-2.4.1-py3-none-any.whl size=25789 sha256=34ffd847fdd539bd9e290b96063ef8fac2ebd3f6600b85abd6bfb9d968ac3f23
#   Stored in directory: /root/.cache/pip/wheels/82/a3/c5/364155118f298722dff2f79ae4dd7c91e92b433ad36d6f7e0e
# Successfully built google-search-results
# ...

# %%
# !unzip "/content/drive/My Drive/newest_data.zip" -d '/content/dataset'
# Out:
# Archive:  /content/drive/My Drive/newest_data.zip
#    creating: /content/dataset/daata/
#    creating: /content/dataset/daata/caricature/
#   inflating: /content/dataset/daata/caricature/001.jpg
#   inflating: /content/dataset/daata/caricature/002.jpg
#   inflating: /content/dataset/daata/caricature/003.jpg
#   inflating: /content/dataset/daata/caricature/004.jpg
#   inflating: /content/dataset/daata/caricature/005.jpg
#   inflating: /content/dataset/daata/caricature/006.jpg
#   inflating: /content/dataset/daata/caricature/007.jpg
#   inflating: /content/dataset/daata/caricature/008.jpg
#   inflating: /content/dataset/daata/caricature/009.jpg
#   inflating: /content/dataset/daata/caricature/010.jpg
#   inflating: /content/dataset/daata/caricature/011.jpg
#   inflating: /content/dataset/daata/caricature/012.jpg
#   inflating: /content/dataset/daata/caricature/013.jpg
#   inflating: /content/dataset/daata/caricature/014.jpg
#   inflating: /content/dataset/daata/caricature/015.jpg
# ...

# %%
carric_dir = '/content/dataset/daata/caricature/'

# %%
import os 
lis_carac = os.listdir(carric_dir)

# %%
print(carric_dir+lis_carac[0])
# Out:
# /content/dataset/daata/caricature/531.jpg

# %%
# !pip install imgurpython
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#   Created wheel for imgurpython: filename=imgurpython-1.1.7-py3-none-any.whl size=12571 sha256=8ff803445ef7381f35b2dd99a2ebb98a0bd5a9a0029fab1c9264820b097e1ee5
#   Stored in directory: /root/.cache/pip/wheels/9b/fd/79/5a06e57d74315305af6d85ecc402a96036edf7c4e1426c7626
# Successfully built imgurpython
# ...

# %%
from imgurpython import ImgurClient

client_id = 'ba96b3864bb80b0'
client_secret = '7760c396ddd2f5423790bc49b2758dc28614bdd4'

client = ImgurClient(client_id, client_secret)

# Example request
list_links = []
items = client.gallery()
for item in items:
    print(item.link)
    list_links.append(item.link)
# Out:
# https://imgur.com/a/5qRHKIh
# https://imgur.com/a/7UxlMoa
# https://imgur.com/a/Ky8zmrw
# https://imgur.com/a/YX6GFzH
# https://imgur.com/a/9yHkhxw
# https://imgur.com/a/HgYFtbP
# https://imgur.com/a/kBuA06j
# https://imgur.com/a/S6zrkeY
# https://imgur.com/a/vTbuUdM
# https://imgur.com/a/9qFnXYF
# https://imgur.com/a/1JqjMji
# https://imgur.com/a/SNDQtLb
# https://imgur.com/a/qm6LUgp
# https://imgur.com/a/cn5HeHO
# https://imgur.com/a/xU4sZI0
# https://imgur.com/a/zqS93Oi
# https://imgur.com/a/l5V4bgs
# https://imgur.com/a/1itMVoV
# https://imgur.com/a/90XTpht
# https://imgur.com/a/E6mygCr
# https://imgur.com/a/91kieUo
# https://imgur.com/a/EyWz0Yq
# https://imgur.com/a/WrA3pih
# https://imgur.com/a/TVv3Pct
# https://imgur.com/a/aWRWgwn
# https://imgur.com/a/cRc6IE4
# https://imgur.com/a/oXTPjqy
# https://imgur.com/a/P3ETy9X
# https://imgur.com/a/SEzAKe4
# https://imgur.com/a/05OVy1o
# https://imgur.com/a/aEnTPoE
# https://imgur.com/a/cMlYRIJ
# https://imgur.com/a/2jA4n7u
# ...

# %%
list_links = []

len(list_links)
# Out:
# 0

# %%
from serpapi import GoogleSearch
list_json = []
for i in caricature_list_links : 
  params = {
    "engine": "google_reverse_image",
    "image_url": i,
    "api_key": "8050972f1315107e73c275992969eda4ce4499e7d7424b26e46071c03abf3786"
  }

  search = GoogleSearch(params)
  results = search.get_dict()
  list_json.append(results)
# Out:
# https://serpapi.com/search
# https://serpapi.com/search
# https://serpapi.com/search
# https://serpapi.com/search
# https://serpapi.com/search
# https://serpapi.com/search
# https://serpapi.com/search
# https://serpapi.com/search
# https://serpapi.com/search
# https://serpapi.com/search
# https://serpapi.com/search
# https://serpapi.com/search
# https://serpapi.com/search
# https://serpapi.com/search
# https://serpapi.com/search
# https://serpapi.com/search
# https://serpapi.com/search
# https://serpapi.com/search
# https://serpapi.com/search
# https://serpapi.com/search
# https://serpapi.com/search
# https://serpapi.com/search
# https://serpapi.com/search
# https://serpapi.com/search
# https://serpapi.com/search
# https://serpapi.com/search
# https://serpapi.com/search
# https://serpapi.com/search
# https://serpapi.com/search
# https://serpapi.com/search
# https://serpapi.com/search
# https://serpapi.com/search
# https://serpapi.com/search
# https://serpapi.com/search
# ...

# %%
txt_file = open("caricature.txt", "r")
file_content =txt_file.read().splitlines()
print(file_content)
# Out:
# ['https://i.imgur.com/HbVbr5Y.jpg', 'https://i.imgur.com/0yef573.jpg', 'https://i.imgur.com/MFgtQ6F.jpg', 'https://i.imgur.com/3wyqmeS.jpg', 'https://i.imgur.com/8fxXYMS.jpg', 'https://i.imgur.com/V4ZPLce.jpg', 'https://i.imgur.com/eS0JvXF.jpg', 'https://i.imgur.com/eeA62Wy.jpg', 'https://i.imgur.com/mpmhRLm.jpg', 'https://i.imgur.com/hPCe5bp.jpg', 'https://i.imgur.com/5jrxZFP.jpg', 'https://i.imgur.com/aXzr1Am.jpg', 'https://i.imgur.com/QqFIbte.jpg', 'https://i.imgur.com/1YXWlg7.jpg', 'https://i.imgur.com/vIRnwd8.jpg', 'https://i.imgur.com/JQJjimg.jpg', 'https://i.imgur.com/NgC3Fpw.jpg', 'https://i.imgur.com/WmJXIpr.jpg', 'https://i.imgur.com/frP1YQH.jpg', 'https://i.imgur.com/8a2bp37.jpg', 'https://i.imgur.com/grK775U.jpg', 'https://i.imgur.com/t5lNMYk.jpg', 'https://i.imgur.com/aPM0VsH.jpg', 'https://i.imgur.com/9vwmTpH.jpg', 'https://i.imgur.com/82W3bbt.jpg', 'https://i.imgur.com/YklPCxs.jpg', 'https://i.imgur.com/mhNzHzq.jpg', 'https://i.imgur.com/b6k7tcG.jpg', 'https://i.imgur.
# ...

# %%
list_links = file_content

# %%
list_links
# Out:
# ['https://i.imgur.com/HbVbr5Y.jpg',
#  'https://i.imgur.com/0yef573.jpg',
#  'https://i.imgur.com/MFgtQ6F.jpg',
#  'https://i.imgur.com/3wyqmeS.jpg',
#  'https://i.imgur.com/8fxXYMS.jpg',
#  'https://i.imgur.com/V4ZPLce.jpg',
#  'https://i.imgur.com/eS0JvXF.jpg',
#  'https://i.imgur.com/eeA62Wy.jpg',
#  'https://i.imgur.com/mpmhRLm.jpg',
#  'https://i.imgur.com/hPCe5bp.jpg',
#  'https://i.imgur.com/5jrxZFP.jpg',
#  'https://i.imgur.com/aXzr1Am.jpg',
#  'https://i.imgur.com/QqFIbte.jpg',
#  'https://i.imgur.com/1YXWlg7.jpg',
#  'https://i.imgur.com/vIRnwd8.jpg',
#  'https://i.imgur.com/JQJjimg.jpg',
#  'https://i.imgur.com/NgC3Fpw.jpg',
#  'https://i.imgur.com/WmJXIpr.jpg',
#  'https://i.imgur.com/frP1YQH.jpg',
#  'https://i.imgur.com/8a2bp37.jpg',
#  'https://i.imgur.com/grK775U.jpg',
#  'https://i.imgur.com/t5lNMYk.jpg',
#  'https://i.imgur.com/aPM0VsH.jpg',
#  'https://i.imgur.com/9vwmTpH.jpg',
#  'https://i.imgur.com/82W3bbt.jpg',
#  'https://i.imgur.com/YklPCxs.jpg',
# ...

# %%
list_json

# %%
caricature_file = open("manifestation_file.txt", "w")
caricature_file.write(str(list_json))
# Out:
# 35938869

# %%
import pickle
with open("file", 'wb') as fp:
    # indent=2 is not needed but makes the file human-readable 
    # if the data is nested
    pickle.dump(list_json,fp)

# %%
print(file_content)
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %%
# !jupyter notebook --NotebookApp.iopub_data_rate_limit=1.0e10
# Out:
# Traceback (most recent call last):
#   File "/usr/local/bin/jupyter-notebook", line 8, in <module>
#     sys.exit(main())
#   File "/usr/local/lib/python3.7/dist-packages/jupyter_core/application.py", line 269, in launch_instance
#     return super().launch_instance(argv=argv, **kwargs)
#   File "/usr/local/lib/python3.7/dist-packages/traitlets/config/application.py", line 845, in launch_instance
#     app.initialize(argv)
#   File "/usr/local/lib/python3.7/dist-packages/traitlets/config/application.py", line 88, in inner
#     return method(app, *args, **kwargs)
#   File "/usr/local/lib/python3.7/dist-packages/notebook/notebookapp.py", line 1507, in initialize
#     self.init_webapp()
#   File "/usr/local/lib/python3.7/dist-packages/notebook/notebookapp.py", line 1297, in init_webapp
#     self.http_server.listen(port, self.ip)
#   File "/usr/local/lib/python3.7/dist-packages/tornado/tcpserver.py", line 143, in listen
#     sockets = bind_sockets(port, address=address)
# ...

# %%
from serpapi import GoogleSearch

params = {
    "engine": "google_reverse_image",
    "image_url": 'https://i.ibb.co/WHgQkjS/988.jpg',
    "api_key": "5b4a66707662ff22cdec45b8c4af6c3762421912a795b9c10e893e9325dc2de1"
  }

search = GoogleSearch(params)
results = search.get_dict()
print(results)
# Out:
# https://serpapi.com/search
# ...

# %%
txt_file = open("caricature_links.txt", "r")
file_content =txt_file.read().splitlines()
print(file_content)
# Out:
# ['/5xsYfRK][img]https://i.ibb.co/h12XtmY/001.jpg', '/g4TtvZg][img]https://i.ibb.co/NTjW12Y/002.jpg', '/N9pHk2M][img]https://i.ibb.co/c6t7phj/003.jpg', '[url=/][img]https://i.ibb.co/3RBk2jG/004.jpg', '/3sMfk56][img]https://i.ibb.co/QcC8X7S/005.jpg', '/9cZ36Ym][img]https://i.ibb.co/BcnKbsH/006.jpg', '/M2BfJGn][img]https://i.ibb.co/w0c72wy/007.jpg', '/LNfg1b6][img]https://i.ibb.co/KKHsWR7/008.jpg', '[url=/][img]https://i.ibb.co/WgF1Xyp/009.jpg', '/DMHbGg0][img]https://i.ibb.co/gWL7vFk/010.jpg', '/DMHbGg0][img]https://i.ibb.co/gWL7vFk/010.jpg', '/sVGmrJz][img]https://i.ibb.co/S38sp7G/012.jpg', '[url=/][img]https://i.ibb.co/wR7qbm8/013.jpg', '[url=/][img]https://i.ibb.co/wR7qbm8/013.jpg', '[url=/][img]https://i.ibb.co/qD5Zb35/015.jpg', '/rpjd4Kd][img]https://i.ibb.co/gW24zb4/016.jpg', '[url=/][img]https://i.ibb.co/Czw7YDs/017.jpg', '[url=/][img]https://i.ibb.co/yVXnfTC/018.jpg', '[url=/][img]https://i.ibb.co/R0r6t3b/019.jpg', '/gVzd01Z][img]https://i.ibb.co/4dP2byR/020.jpg', '[url=/][img]
# ...

# %%
manif_list_links = []
for i in file_content : 
  index = i.index('http')
  manif_list_links.append(i[index:])
print(manif_list_links)
# Out:
# ['https://i.ibb.co/PMJWsMF/image.jpg', 'https://i.ibb.co/r58KXWd/001.jpg', 'https://i.ibb.co/ZGLrCCr/1.jpg', 'https://i.ibb.co/VMQ837q/002.jpg', 'https://i.ibb.co/n0bDtX2/2.jpg', 'https://i.ibb.co/dgJrfFh/003.jpg', 'https://i.ibb.co/zmScdsT/3.jpg', 'https://i.ibb.co/MDg9vpq/004.jpg', 'https://i.ibb.co/3Wps2kg/4.jpg', 'https://i.ibb.co/HX5VM4F/5.jpg', 'https://i.ibb.co/n3nsjYv/6.jpg', 'https://i.ibb.co/5RQ9Jvg/7.jpg', 'https://i.ibb.co/BqLc8v9/8.jpg', 'https://i.ibb.co/CtwsGbL/9.jpg', 'https://i.ibb.co/zr7BQCc/10.jpg', 'https://i.ibb.co/hRZF2cw/11.jpg', 'https://i.ibb.co/pRjpmjc/12.jpg', 'https://i.ibb.co/zN37N6d/13.jpg', 'https://i.ibb.co/nwyRSgb/14.jpg', 'https://i.ibb.co/X573dDK/15.jpg', 'https://i.ibb.co/Lx65WK3/16.jpg', 'https://i.ibb.co/9485XDt/17.jpg', 'https://i.ibb.co/60qNGp9/18.jpg', 'https://i.ibb.co/wLHxMsz/19.jpg', 'https://i.ibb.co/1v3Bpkx/20.jpg', 'https://i.ibb.co/hR7dQr3/21.jpg', 'https://i.ibb.co/GM4WTwz/22.jpg', 'https://i.ibb.co/5B11mKr/23.jpg', 'https://i.ibb.co/Y
# ...

# %%
caricature_list_links = []
for i in file_content : 
  index = i.index('http')
  caricature_list_links.append(i[index:])
print(caricature_list_links)
# Out:
# ['https://i.ibb.co/h12XtmY/001.jpg', 'https://i.ibb.co/NTjW12Y/002.jpg', 'https://i.ibb.co/c6t7phj/003.jpg', 'https://i.ibb.co/3RBk2jG/004.jpg', 'https://i.ibb.co/QcC8X7S/005.jpg', 'https://i.ibb.co/BcnKbsH/006.jpg', 'https://i.ibb.co/w0c72wy/007.jpg', 'https://i.ibb.co/KKHsWR7/008.jpg', 'https://i.ibb.co/WgF1Xyp/009.jpg', 'https://i.ibb.co/gWL7vFk/010.jpg', 'https://i.ibb.co/gWL7vFk/010.jpg', 'https://i.ibb.co/S38sp7G/012.jpg', 'https://i.ibb.co/wR7qbm8/013.jpg', 'https://i.ibb.co/wR7qbm8/013.jpg', 'https://i.ibb.co/qD5Zb35/015.jpg', 'https://i.ibb.co/gW24zb4/016.jpg', 'https://i.ibb.co/Czw7YDs/017.jpg', 'https://i.ibb.co/yVXnfTC/018.jpg', 'https://i.ibb.co/R0r6t3b/019.jpg', 'https://i.ibb.co/4dP2byR/020.jpg', 'https://i.ibb.co/xHHK4pj/021.jpg', 'https://i.ibb.co/QXPGZg3/022.jpg', 'https://i.ibb.co/Gph9vGP/023.jpg', 'https://i.ibb.co/SRSK6qR/024.jpg', 'https://i.ibb.co/54k2NqL/025.jpg', 'https://i.ibb.co/zsFnbB9/026.jpg', 'https://i.ibb.co/9wFfRkq/027.jpg', 'https://i.ibb.co/n88rrYC
# ...

# %%
with open("file", "rb") as fp: 
  b = pickle.load(fp)

# %%
b

# %%
b[1]
# Out:
# {'image_results': [{'date': 'Nov 19, 2018',
#    'displayed_link': 'https://france3-regions.francetvinfo.fr › ...',
#    'link': 'https://france3-regions.francetvinfo.fr/auvergne-rhone-alpes/puy-de-dome/clermont-ferrand/gilets-jaunes-non-clermont-ferrand-il-n-y-avait-pas-50-000-manifestants-place-jaude-1577752.html',
#    'position': 1,
#    'snippet': 'Une photo diffusée sur Facebook montre la place de Jaude à Clermont-Ferrand bondée. Selon la légende, elle illustre le rassemblement des ...',
#    'snippet_highlighted_words': ['place de Jaude', 'Clermont', 'Ferrand'],
#    'title': "Gilets jaunes : non à Clermont-Ferrand, il n'y avait pas 50 000 ..."},
#   {'date': 'Feb 24, 2019',
#    'displayed_link': 'https://france3-regions.francetvinfo.fr › ...',
#    'link': 'https://france3-regions.francetvinfo.fr/auvergne-rhone-alpes/puy-de-dome/clermont-ferrand/clermont-ferrand-non-il-n-y-avait-pas-55-000-gilets-jaunes-place-jaude-aucun-helicoptere-n-tire-foule-1628961.html',
# ...
