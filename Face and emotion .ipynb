# %% [markdown]
# # Face Detection

# %%
# !pip3 install face_recognition
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting face_recognition
#   Downloading face_recognition-1.3.0-py2.py3-none-any.whl (15 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from face_recognition) (1.21.6)
# Requirement already satisfied: Click>=6.0 in /usr/local/lib/python3.7/dist-packages (from face_recognition) (7.1.2)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.7/dist-packages (from face_recognition) (7.1.2)
# Collecting face-recognition-models>=0.3.0
#   Downloading face_recognition_models-0.3.0.tar.gz (100.1 MB)
#      |████████████████████████████████| 100.1 MB 26 kB/s
# Requirement already satisfied: dlib>=19.7 in /usr/local/lib/python3.7/dist-packages (from face_recognition) (19.18.0+zzzcolab20220513001918)
# Building wheels for collected packages: face-recognition-models
#   Building wheel for face-recognition-models (setup.py) ... done
#   Created wheel for face-recognition-models: filename=face_recognition_models-0.3.0-py2.py3-none-any.whl size=100566186 sha256=40d2bedb009ab36ad0d7a4d2abbc1d0adf980b9fc0c923ee4119c9666776ff2a
#   Stored in directory: /root/.cache/pip/wheels/d6/81/3c/884bcd5e1c120ff548d57c2ecc9ebf3281c9a6f7c0e7e7947a
# Successfully built face-recognition-models
# Installing collected packages: face-recognition-models, face-recognition
# Successfully installed face-recognition-1.3.0 face-recognition-models-0.3.0

# %%
from google.colab import drive
drive.mount('/content/drive',force_remount=True)
# Out:
# Mounted at /content/drive

# %%
base_dir = '/content/dataset_visite/Images-visiteNVB-Bourdarias/'

# %%
# !unzip "/content/drive/My Drive/Images-visiteNVB-Bourdarias.zip" -d '/content/dataset_visite'
# Out:
# Archive:  /content/drive/My Drive/Images-visiteNVB-Bourdarias.zip
#    creating: /content/dataset_visite/Images-visiteNVB-Bourdarias/
#  extracting: /content/dataset_visite/Images-visiteNVB-Bourdarias/0-Capture d’écran 2021-06-27 à 22.57.00.png
#  extracting: /content/dataset_visite/Images-visiteNVB-Bourdarias/1-7dece12762d04e66e8e640ce636b4dc0a9bda222 copie.jpg
#  extracting: /content/dataset_visite/Images-visiteNVB-Bourdarias/1-823fb43f5a5c11dee5d7f12f34278156e5d87bec copie.jpg
#  extracting: /content/dataset_visite/Images-visiteNVB-Bourdarias/1-84d104622bfd032ac6753465545cbb5ddcf9d322 copie.jpg
#  extracting: /content/dataset_visite/Images-visiteNVB-Bourdarias/1-88258089fe00039eac37480138567b159826475a copie.jpg
#  extracting: /content/dataset_visite/Images-visiteNVB-Bourdarias/1-8d759d1827902d3c76345aad596dbd07d7e78dc1 copie.jpg
#  extracting: /content/dataset_visite/Images-visiteNVB-Bourdarias/1-fa82413cc343f62a5c68fce6a54ab817b57991ba.jpg
#  extracting: /content/dataset_visite/Images-visiteNVB-Bourdarias/1f9d01f6f3868ef4eda453a896617ba0551e75c9 copie.jpg
#  extracting: /content/dataset_visite/Images-visiteNVB-Bourdarias/2-0f666d5f51f2c5cf69a5885804b93623aa44db70 copie.jpg
#  extracting: /content/dataset_visite/Images-visiteNVB-Bourdarias/2-234498bfcf1a045b498e5d194188bd33b4cdda3b copie.jpg
#  extracting: /content/dataset_visite/Images-visiteNVB-Bourdarias/2-937fc8a7dca95b0e238fe772622e506716b520d0 copie.jpg
#  extracting: /content/dataset_visite/Images-visiteNVB-Bourdarias/2-Capture d’écran 2021-07-03 à 16.47.16.png
#  extracting: /content/dataset_visite/Images-visiteNVB-Bourdarias/2-Capture d’écran 2021-07-12 à 00.08.09.png
#  extracting: /content/dataset_visite/Images-visiteNVB-Bourdarias/2-adc6632348c8312c31368d185b9074cc7eff919b copie.jpg
#  extracting: /content/dataset_visite/Images-visiteNVB-Bourdarias/2-af79599d8ccc6975a5a272ded4fef710ded2e567 copie.jpg
#  extracting: /content/dataset_visite/Images-visiteNVB-Bourdarias/2-bf79fdaf8b89a9d47ca07e853c49f0fda38fa440 copie.jpg
#  extracting: /content/dataset_visite/Images-visiteNVB-Bourdarias/2-cec2f51e19cb4ec5077758091e2b8b4c3781f578 copie.jpg
#  extracting: /content/dataset_visite/Images-visiteNVB-Bourdarias/2-najad-educatie-gen-scoli.jpg
#  extracting: /content/dataset_visite/Images-visiteNVB-Bourdarias/caricature-b06f0c4d94e7f63d06268d69e7981266e6e1b35a copie.jpg

# %%
import face_recognition


image = face_recognition.load_image_file(base_dir+images[0])

face_locations = face_recognition.face_locations(image)
top, right, bottom, left = face_locations[0]
face_image = image[top:bottom, left:right]

# %%
import os 
images  = os.listdir(base_dir)

# %%
face_locations
# Out:
# [(41, 261, 84, 218), (50, 413, 86, 377)]

# %%
from PIL import Image
from matplotlib import pyplot as plt
import numpy as np
import face_recognition
import keras
from keras.models import load_model
import cv2

# %%
top, right, bottom, left = face_locations[0]
face_image1 = image[top:bottom, left:right]
plt.imshow(face_image1)
image_save = Image.fromarray(face_image1)
image_save.save("image_1.jpg")

# %%
top, right, bottom, left = face_locations[1]
face_image1 = image[top:bottom, left:right]
plt.imshow(face_image1)
image_save = Image.fromarray(face_image1)
image_save.save("image_1.jpg")

# %%
plt.imshow(image)

# %%
emotion_dict= {'Angry': 0, 'Sad': 5, 'Neutral': 4, 'Disgust': 1, 'Surprise': 6, 'Fear': 2, 'Happy': 3}

# %%
face_image = cv2.imread(base_dir+images[0])
face_image = cv2.resize(face_image, (48,48))
face_image = cv2.cvtColor(face_image, cv2.COLOR_BGR2GRAY)
face_image = np.reshape(face_image, [1, face_image.shape[0], face_image.shape[1], 1])

# %%
model = load_model("/content/model_v6_23.hdf5")

# %%
predicted_class = np.argmax(model.predict(face_image))

# %%
label_map = dict((v,k) for k,v in emotion_dict.items()) 
predicted_label = label_map[predicted_class]

# %%
print(predicted_label)
# Out:
# Surprise
